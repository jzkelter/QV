# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import matplotlib     
font = {'size'   : 12}
matplotlib.rc('font', **font)

# %%
def color(x):
    if x == "1. prop8-mean>0":
        return 'blue'
    else:
        return 'orange'



df = pd.read_csv('QV Prop8 correlating pmp with utilities data.csv')
df['wellfare-loss'] = 1 - df['mean payoff-sign-list']
df['color'] = df['calibration'].apply(color)

df2 = pd.read_csv('QV varying-mean-utility-table.csv')
df2['wellfare-loss'] = 1 - df2['average payoff']


display(df)

display(df2)
# Out:
#     [run number]  payoff-include-votes-cost? behavior-under-qv  \
# 0              7                       False          rational
# 1              4                       False          rational
# 2              8                       False          rational
# 3              3                       False          rational
# 4              6                       False          rational
# ..           ...                         ...               ...
# 77            78                       False          rational
# 78            79                       False          rational
# 79            81                       False          rational
# 80            80                       False          rational
# 81            82                       False          rational
#
#         calibration  variance-of-pmp  number-of-voters voting-mechanism  \
# 0   1. prop8-mean>0             0.01              1001               QV
# 1   1. prop8-mean>0             0.01              1001               QV
# 2   1. prop8-mean>0             0.01              1001               QV
# 3   1. prop8-mean>0             0.01              1001               QV
# 4   1. prop8-mean>0             0.01              1001               QV
# ..              ...              ...               ...              ...
# 77  2. prop8-mean=0             0.01              1001               QV
# 78  2. prop8-mean=0             0.01              1001               QV
# 79  2. prop8-mean=0             0.01              1001               QV
# 80  2. prop8-mean=0             0.01              1001               QV
# 81  2. prop8-mean=0             0.01              1001               QV
#
#     marginal-pivotality  utility-pmp-correlation  limit-votes?  [step]  \
# 0                   0.5                    -0.70         False    1000
# 1                   0.5                    -0.85         False    1000
# 2                   0.5                    -0.65         False    1000
# 3                   0.5                    -0.90         False    1000
# 4                   0.5                    -0.75         False    1000
# ..                  ...                      ...           ...     ...
# 77                  0.5                     0.80         False    1000
# 78                  0.5                     0.85         False    1000
# 79                  0.5                     0.95         False    1000
# 80                  0.5                     0.90         False    1000
# 81                  0.5                     1.00         False    1000
#
#     mean payoff-sign-list  wellfare-loss   color
# 0                   0.999          0.001    blue
# 1                   1.000          0.000    blue
# 2                   1.000          0.000    blue
# 3                   1.000          0.000    blue
# 4                   0.999          0.001    blue
# ..                    ...            ...     ...
# 77                  0.934          0.066  orange
# 78                  0.950          0.050  orange
# 79                  0.930          0.070  orange
# 80                  0.934          0.066  orange
# 81                  0.933          0.067  orange
#
# [82 rows x 14 columns]
#       [run number]  payoff-include-votes-cost?  majority-mean-utility  \
# 0                1                       False                    0.0
# 1              127                       False                    0.0
# 2              253                       False                    0.0
# 3              379                       False                    0.0
# 4              505                       False                    0.0
# ...            ...                         ...                    ...
# 1255           756                       False                    0.1
# 1256           882                       False                    0.1
# 1257          1008                       False                    0.1
# 1258          1134                       False                    0.1
# 1259          1260                       False                    0.1
#
#       majority-utility-stdev behavior-under-qv calibration  variance-of-pmp  \
# 0                          1          rational      manual             0.01
# 1                          1          rational      manual             0.01
# 2                          1          rational      manual             0.01
# 3                          1          rational      manual             0.01
# 4                          1          rational      manual             0.01
# ...                      ...               ...         ...              ...
# 1255                       1          rational      manual             0.01
# 1256                       1          rational      manual             0.01
# 1257                       1          rational      manual             0.01
# 1258                       1          rational      manual             0.01
# 1259                       1          rational      manual             0.01
#
#       number-of-voters voting-mechanism  marginal-pivotality  \
# 0                 1001               QV                  0.5
# 1                 1001               QV                  0.5
# 2                 1001               QV                  0.5
# 3                 1001               QV                  0.5
# 4                 1001               QV                  0.5
# ...                ...              ...                  ...
# 1255              1001               QV                  0.5
# 1256              1001               QV                  0.5
# 1257              1001               QV                  0.5
# 1258              1001               QV                  0.5
# 1259              1001               QV                  0.5
#
#       utility-pmp-correlation  limit-votes?  [step]  mean payoff-sign-list  \
# 0                        -1.0         False     100                   0.89
# 1                        -1.0         False     100                   0.95
# 2                        -1.0         False     100                   0.96
# 3                        -1.0         False     100                   0.94
# 4                        -1.0         False     100                   0.94
# ...                       ...           ...     ...                    ...
# 1255                      1.0         False     100                   1.00
# 1256                      1.0         False     100                   1.00
# 1257                      1.0         False     100                   1.00
# 1258                      1.0         False     100                   1.00
# 1259                      1.0         False     100                   1.00
#
#       average payoff  wellfare-loss
# 0              0.931          0.069
# 1              0.931          0.069
# 2              0.931          0.069
# 3              0.931          0.069
# 4              0.931          0.069
# ...              ...            ...
# 1255           0.998          0.002
# 1256           0.998          0.002
# 1257           0.998          0.002
# 1258           0.998          0.002
# 1259           0.998          0.002
#
# [1260 rows x 16 columns]

# %%
ax = sns.scatterplot(x="utility-pmp-correlation", 
                     y="wellfare-loss",
                     hue="color",
                     data = df)
plt.title("blue='1.prop8-mean>0'  orange='2.prop8-mean=0'")
# Out:
# Text(0.5, 1.0, "blue='1.prop8-mean>0'  orange='2.prop8-mean=0'")

# %% [markdown]
# Now lets confirm the differences in trends that we see above: Correlating pmp with utilities will rarely swing a vote when it's mean utility is far from zero, any "noise" that it would generate wouldn't matter because the vote would still be made in the same direction as the one that would minimize wellfare-loss.

# %%
adf2 = df2[df2["majority-mean-utility"] == 0]
ax2 = sns.scatterplot(x="utility-pmp-correlation", 
                      y="wellfare-loss",
                      data = adf2)
adf2 = df2[df2["majority-mean-utility"] == 0.1]

ax2 = sns.scatterplot(x="utility-pmp-correlation", 
                      y="wellfare-loss",
                      data = adf2)

adf2 = df2[df2["majority-mean-utility"] == 0.08]

ax2 = sns.scatterplot(x="utility-pmp-correlation", 
                      y="wellfare-loss",
                      data = adf2)
plt.title("mean= blue(0), green(0.08), orange(0.1)")
# Out:
# Text(0.5, 1.0, 'mean= blue(0), green(0.08), orange(0.1)')

# %% [markdown]
# I can run this for more repetitions, but I would need more time (ballpark 6-8 hours for one run on my laptop, maybe less on my desktop), because if we want to use wellfare-loss, then we have to use mean payoff-sign-list which is only accurate after running for 100+ repetitions. I can use a different method of measuring overall wellbeing, but then we run into issues of not being normalized well (in other words, if we use payoff as our metric, a mean that is farther away from 0 will result in a higher overall payoff).

# %%
df3 = pd.read_csv('QV passionate-minority-pmp-correlation-table.csv')
df3['wellfare-loss'] = 1 - df3['Unnamed: 17']
df3['wellfare-loss range'] = 1 - df3['mean payoff-sign-list']

display(df3)


ax = sns.scatterplot(x="utility-pmp-correlation", 
                     y="wellfare-loss range",
                      color = "orange",
                     data = df3)

ax2 = sns.scatterplot(x="utility-pmp-correlation", 
                     y="wellfare-loss",
                     color = "blue",
                     data = df3)
plt.title("passionate minority, varying utility-pmp correlation")
# Out:
#       [run number]  payoff-include-votes-cost?  majority-mean-utility  \
# 0                5                       False                     -4
# 1                7                       False                     -4
# 2                8                       False                     -4
# 3                4                       False                     -4
# 4                3                       False                     -4
# ...            ...                         ...                    ...
# 2095          2096                       False                     -4
# 2096          2097                       False                     -4
# 2097          2098                       False                     -4
# 2098          2099                       False                     -4
# 2099          2100                       False                     -4
#
#       majority-utility-stdev  minority-mean-utility  minority-utility-stdev  \
# 0                          1                      6                       1
# 1                          1                      6                       1
# 2                          1                      6                       1
# 3                          1                      6                       1
# 4                          1                      6                       1
# ...                      ...                    ...                     ...
# 2095                       1                      6                       1
# 2096                       1                      6                       1
# 2097                       1                      6                       1
# 2098                       1                      6                       1
# 2099                       1                      6                       1
#
#       minority-fraction behavior-under-qv calibration  variance-of-pmp  \
# 0                   0.4          rational      manual             0.01
# 1                   0.4          rational      manual             0.01
# 2                   0.4          rational      manual             0.01
# 3                   0.4          rational      manual             0.01
# 4                   0.4          rational      manual             0.01
# ...                 ...               ...         ...              ...
# 2095                0.4          rational      manual             0.01
# 2096                0.4          rational      manual             0.01
# 2097                0.4          rational      manual             0.01
# 2098                0.4          rational      manual             0.01
# 2099                0.4          rational      manual             0.01
#
#       number-of-voters voting-mechanism  marginal-pivotality  \
# 0                 1001               QV                  0.5
# 1                 1001               QV                  0.5
# 2                 1001               QV                  0.5
# 3                 1001               QV                  0.5
# 4                 1001               QV                  0.5
# ...                ...              ...                  ...
# 2095              1001               QV                  0.5
# 2096              1001               QV                  0.5
# 2097              1001               QV                  0.5
# 2098              1001               QV                  0.5
# 2099              1001               QV                  0.5
#
#       utility-pmp-correlation  limit-votes?  [step]  mean payoff-sign-list  \
# 0                        -1.0         False     100                   0.77
# 1                        -1.0         False     100                   0.81
# 2                        -1.0         False     100                   0.79
# 3                        -1.0         False     100                   0.75
# 4                        -1.0         False     100                   0.81
# ...                       ...           ...     ...                    ...
# 2095                      1.0         False     100                   0.89
# 2096                      1.0         False     100                   0.91
# 2097                      1.0         False     100                   0.88
# 2098                      1.0         False     100                   0.93
# 2099                      1.0         False     100                   0.87
#
#       Unnamed: 17  wellfare-loss  wellfare-loss range
# 0          0.7813         0.2187                 0.23
# 1          0.7813         0.2187                 0.19
# 2          0.7813         0.2187                 0.21
# 3          0.7813         0.2187                 0.25
# 4          0.7813         0.2187                 0.19
# ...           ...            ...                  ...
# 2095       0.8619         0.1381                 0.11
# 2096       0.8619         0.1381                 0.09
# 2097       0.8619         0.1381                 0.12
# 2098       0.8619         0.1381                 0.07
# 2099       0.8619         0.1381                 0.13
#
# [2100 rows x 20 columns]
# Text(0.5, 1.0, 'passionate minority, varying utility-pmp correlation')
